# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten,Conv2D,MaxPool2D,BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1_l2,l2

with open('/content/drive/MyDrive/781_Project/gtzan_mfcc.json', "r") as file:
    data = json.load(file) #Load MFCC dataset from JSON file

X = np.array(data["mfcc"]) #Load MFCCs 
y = np.array(data["labels"]) #Load corresponding genre names



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=0) #Splitting data into random training and test sets

# %%
X_train = X_train[..., np.newaxis] #Increase dimension of array by one
X_test = X_test[..., np.newaxis] #Increase dimension of array by one

# %%
from keras.callbacks import ReduceLROnPlateau
rlrop = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=4) #Reduce learning rate when a metric has stopped improving

model = Sequential() #Initializing a sequential model


model.add(Conv2D(256,kernel_size=(5,5),input_shape=(X_train.shape[1],X_train.shape[2],1),padding='same',kernel_initializer='he_uniform')) #Add a 2D convolution layer
model.add(BatchNormalization()) #Add a layer to normalize the inputs
model.add(MaxPool2D(pool_size=(2,2))) #Add a layer for max pooling operation on 2D spatial data

model.add(Conv2D(128, kernel_size = (5,5),activation ='relu',padding='same', kernel_initializer='he_uniform')) #Add a 2D convolution layer
model.add(BatchNormalization()) #Add a layer to normalize the inputs
model.add(MaxPool2D(pool_size=(2,2))) #Add a layer for max pooling operation on 2D spatial data


model.add(Conv2D(64, kernel_size = (5,5),activation ='relu',padding='same', kernel_initializer='he_uniform')) #Add a 2D convolution layer
model.add(BatchNormalization()) #Add a layer to normalize the inputs
model.add(MaxPool2D(pool_size=(2,2))) #Add a layer for max pooling operation on 2D spatial data


model.add(Flatten()) #Flattens the input vector


model.add(Dense(128, activation = "relu", kernel_initializer='he_uniform')) #Add a densely connected layer to the neural network
model.add(BatchNormalization()) #Add a layer to normalize the inputs
model.add(Dropout(0.2)) #Add dropout to inputs to avoid overfitting 


model.add(Dense(64, activation = "relu", kernel_initializer='he_uniform')) #Add a densely connected layer to the neural network
model.add(BatchNormalization()) #Add a layer to normalize the inputs
model.add(Dropout(0.2)) #Add dropout to inputs to avoid overfitting 


model.add(Dense(10, activation = "softmax")) #Add a densely connected output layer to the neural network

# %%
optimiser = Adam(learning_rate=0.001) #Initialize Adam optimizer for training
model.compile(optimizer=optimiser,loss='sparse_categorical_crossentropy',metrics=['accuracy']) #Configures the model for training

# %%
model.summary() #Prints a string summary of the network
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 130, 13, 256)      6656
#
#  batch_normalization (BatchN  (None, 130, 13, 256)     1024
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 65, 6, 256)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 65, 6, 128)        819328
#
#  batch_normalization_1 (Batc  (None, 65, 6, 128)       512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 3, 128)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 3, 64)         204864
#
#  batch_normalization_2 (Batc  (None, 32, 3, 64)        256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 1, 64)        0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 128)               131200
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 1,173,514
# Trainable params: 1,172,234
# Non-trainable params: 1,280
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=40,verbose=2,callbacks=[rlrop]) #Trains the model for a fixed number of epochs
# Out:
# Epoch 1/40
# 250/250 - 41s - loss: 1.7576 - accuracy: 0.3898 - val_loss: 1.5811 - val_accuracy: 0.4140 - lr: 0.0010 - 41s/epoch - 166ms/step
# Epoch 2/40
# 250/250 - 9s - loss: 1.3414 - accuracy: 0.5179 - val_loss: 1.5974 - val_accuracy: 0.4395 - lr: 0.0010 - 9s/epoch - 36ms/step
# Epoch 3/40
# 250/250 - 9s - loss: 1.1804 - accuracy: 0.5798 - val_loss: 1.2322 - val_accuracy: 0.5510 - lr: 0.0010 - 9s/epoch - 36ms/step
# Epoch 4/40
# 250/250 - 9s - loss: 0.9966 - accuracy: 0.6516 - val_loss: 1.3785 - val_accuracy: 0.5720 - lr: 0.0010 - 9s/epoch - 36ms/step
# Epoch 5/40
# 250/250 - 9s - loss: 0.8735 - accuracy: 0.7047 - val_loss: 1.0474 - val_accuracy: 0.6185 - lr: 0.0010 - 9s/epoch - 36ms/step
# Epoch 6/40
# 250/250 - 9s - loss: 0.7653 - accuracy: 0.7361 - val_loss: 0.9050 - val_accuracy: 0.7025 - lr: 0.0010 - 9s/epoch - 36ms/step
# Epoch 7/40
# 250/250 - 9s - loss: 0.6899 - accuracy: 0.7616 - val_loss: 0.7260 - val_accuracy: 0.7485 - lr: 0.0010 - 9s/epoch - 37ms/step
# Epoch 8/40
# 250/250 - 9s - loss: 0.6065 - accuracy: 0.8002 - val_loss: 0.8463 - val_accuracy: 0.7135 - lr: 0.0010 - 9s/epoch - 37ms/step
# Epoch 9/40
# 250/250 - 9s - loss: 0.5651 - accuracy: 0.8052 - val_loss: 0.8533 - val_accuracy: 0.7205 - lr: 0.0010 - 9s/epoch - 37ms/step
# Epoch 10/40
# 250/250 - 9s - loss: 0.4797 - accuracy: 0.8367 - val_loss: 0.7066 - val_accuracy: 0.7565 - lr: 0.0010 - 9s/epoch - 37ms/step
# Epoch 11/40
# 250/250 - 9s - loss: 0.4090 - accuracy: 0.8643 - val_loss: 0.6870 - val_accuracy: 0.7700 - lr: 0.0010 - 9s/epoch - 37ms/step
# Epoch 12/40
# 250/250 - 9s - loss: 0.3585 - accuracy: 0.8759 - val_loss: 0.7365 - val_accuracy: 0.7745 - lr: 0.0010 - 9s/epoch - 37ms/step
# Epoch 13/40
# 250/250 - 9s - loss: 0.3344 - accuracy: 0.8866 - val_loss: 1.1729 - val_accuracy: 0.6600 - lr: 0.0010 - 9s/epoch - 36ms/step
# Epoch 14/40
# 250/250 - 9s - loss: 0.3045 - accuracy: 0.8963 - val_loss: 0.6964 - val_accuracy: 0.7780 - lr: 0.0010 - 9s/epoch - 37ms/step
# Epoch 15/40
# 250/250 - 9s - loss: 0.2540 - accuracy: 0.9148 - val_loss: 1.9301 - val_accuracy: 0.6115 - lr: 0.0010 - 9s/epoch - 36ms/step
# Epoch 16/40
# 250/250 - 9s - loss: 0.2385 - accuracy: 0.9193 - val_loss: 0.7303 - val_accuracy: 0.7810 - lr: 0.0010 - 9s/epoch - 37ms/step
# Epoch 17/40
# 250/250 - 9s - loss: 0.2117 - accuracy: 0.9293 - val_loss: 0.7820 - val_accuracy: 0.7715 - lr: 0.0010 - 9s/epoch - 36ms/step
# Epoch 18/40
# 250/250 - 9s - loss: 0.1893 - accuracy: 0.9357 - val_loss: 0.5523 - val_accuracy: 0.8345 - lr: 0.0010 - 9s/epoch - 37ms/step
# Epoch 19/40
# 250/250 - 9s - loss: 0.1699 - accuracy: 0.9433 - val_loss: 0.6584 - val_accuracy: 0.8305 - lr: 0.0010 - 9s/epoch - 36ms/step
# Epoch 20/40
# 250/250 - 9s - loss: 0.1425 - accuracy: 0.9516 - val_loss: 0.7096 - val_accuracy: 0.8030 - lr: 0.0010 - 9s/epoch - 36ms/step
# Epoch 21/40
# 250/250 - 9s - loss: 0.1323 - accuracy: 0.9547 - val_loss: 0.6136 - val_accuracy: 0.8375 - lr: 0.0010 - 9s/epoch - 36ms/step
# Epoch 22/40
# 250/250 - 9s - loss: 0.1383 - accuracy: 0.9530 - val_loss: 0.5891 - val_accuracy: 0.8385 - lr: 0.0010 - 9s/epoch - 36ms/step
# Epoch 23/40
# 250/250 - 9s - loss: 0.1069 - accuracy: 0.9646 - val_loss: 0.6268 - val_accuracy: 0.8350 - lr: 0.0010 - 9s/epoch - 37ms/step
# Epoch 24/40
# 250/250 - 9s - loss: 0.1074 - accuracy: 0.9639 - val_loss: 0.5563 - val_accuracy: 0.8485 - lr: 0.0010 - 9s/epoch - 37ms/step
# Epoch 25/40
# 250/250 - 9s - loss: 0.1024 - accuracy: 0.9671 - val_loss: 0.7272 - val_accuracy: 0.8145 - lr: 0.0010 - 9s/epoch - 36ms/step
# Epoch 26/40
# 250/250 - 9s - loss: 0.0932 - accuracy: 0.9680 - val_loss: 0.6318 - val_accuracy: 0.8340 - lr: 0.0010 - 9s/epoch - 37ms/step
# Epoch 27/40
# 250/250 - 9s - loss: 0.0749 - accuracy: 0.9746 - val_loss: 0.7711 - val_accuracy: 0.8065 - lr: 0.0010 - 9s/epoch - 36ms/step
# Epoch 28/40
# 250/250 - 9s - loss: 0.1155 - accuracy: 0.9605 - val_loss: 0.7435 - val_accuracy: 0.8155 - lr: 0.0010 - 9s/epoch - 36ms/step
# Epoch 29/40
# 250/250 - 9s - loss: 0.0630 - accuracy: 0.9801 - val_loss: 0.4672 - val_accuracy: 0.8725 - lr: 1.0000e-04 - 9s/epoch - 37ms/step
# Epoch 30/40
# 250/250 - 9s - loss: 0.0382 - accuracy: 0.9885 - val_loss: 0.4550 - val_accuracy: 0.8795 - lr: 1.0000e-04 - 9s/epoch - 37ms/step
# Epoch 31/40
# 250/250 - 9s - loss: 0.0307 - accuracy: 0.9910 - val_loss: 0.4453 - val_accuracy: 0.8845 - lr: 1.0000e-04 - 9s/epoch - 36ms/step
# Epoch 32/40
# 250/250 - 9s - loss: 0.0255 - accuracy: 0.9927 - val_loss: 0.4389 - val_accuracy: 0.8850 - lr: 1.0000e-04 - 9s/epoch - 36ms/step
# Epoch 33/40
# 250/250 - 9s - loss: 0.0203 - accuracy: 0.9949 - val_loss: 0.4353 - val_accuracy: 0.8825 - lr: 1.0000e-04 - 9s/epoch - 36ms/step
# Epoch 34/40
# 250/250 - 9s - loss: 0.0210 - accuracy: 0.9939 - val_loss: 0.4365 - val_accuracy: 0.8790 - lr: 1.0000e-04 - 9s/epoch - 37ms/step
# Epoch 35/40
# 250/250 - 9s - loss: 0.0191 - accuracy: 0.9952 - val_loss: 0.4281 - val_accuracy: 0.8885 - lr: 1.0000e-04 - 9s/epoch - 36ms/step
# Epoch 36/40
# 250/250 - 9s - loss: 0.0181 - accuracy: 0.9949 - val_loss: 0.4284 - val_accuracy: 0.8885 - lr: 1.0000e-04 - 9s/epoch - 36ms/step
# Epoch 37/40
# 250/250 - 9s - loss: 0.0174 - accuracy: 0.9956 - val_loss: 0.4265 - val_accuracy: 0.8915 - lr: 1.0000e-04 - 9s/epoch - 36ms/step
# Epoch 38/40
# 250/250 - 9s - loss: 0.0175 - accuracy: 0.9952 - val_loss: 0.4143 - val_accuracy: 0.8880 - lr: 1.0000e-04 - 9s/epoch - 37ms/step
# Epoch 39/40
# 250/250 - 9s - loss: 0.0149 - accuracy: 0.9961 - val_loss: 0.4202 - val_accuracy: 0.8920 - lr: 1.0000e-04 - 9s/epoch - 36ms/step
# Epoch 40/40
# 250/250 - 9s - loss: 0.0120 - accuracy: 0.9969 - val_loss: 0.4245 - val_accuracy: 0.8885 - lr: 1.0000e-04 - 9s/epoch - 37ms/step

# %%
 import matplotlib.pyplot as plt
plt.figure(figsize=(7,7)) #Setting plot dimensions

#Plotting training and test accuracy of model
plt.subplot(2,1,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

#Plotting training and test loss of model
plt.subplot(2,1,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.suptitle('CNN Classification',fontsize=30,y=1.03)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report
labelNames = ['pop','metal','disco','blues','reggae','classical','rock','hiphop','country','jazz']
predictions = model.predict(X_test, batch_size=32) #Use model to predict on the test data

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
matrix = confusion_matrix(y_test, predictions.argmax(axis=1)) #Compute confusion matrix to evaluate the accuracy of a classification
sns.heatmap(matrix,annot=True,fmt='d',yticklabels=labelNames,xticklabels=labelNames) #Plot confusion matrix as a heatmap
plt.title('CNN Classification');

# %%
model.save('/content/drive/MyDrive/781_Project/music_cnn.h5')
